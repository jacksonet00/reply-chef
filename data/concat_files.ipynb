# %%
import pandas as pd

# %%
beauty = pd.read_csv('beauty_ty_comments_dataset.csv')

# %%
finance = pd.read_csv('finance_comments_concat.csv')

# %%
news = pd.read_csv('news_youtube_data_complete.csv')

# %%
tech = pd.read_csv('tech_comments_combined.csv')

# %%
beauty.head()
# Out:
#    Unnamed: 0                                            comment   label
# 0           0  SKIP NAVIGATION\nSIGN IN\nSplitsies :15 | Toni...  beauty
# 1           1  😍 Subscribe to my channel : http://bit.ly/2hjb...  beauty
# 2           2  I don't know why but her voice is oddly satisf...  beauty
# 3           3  Me who doesn't even have half of the stuff I n...  beauty
# 4           4  I  cant believe this is how she actually sound...  beauty

# %%
finance.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                              comment    label
# 0  SKIP NAVIGATION\nSIGN IN\n0:01 / 26:51\nReveal...  finance
# 1  Here is a breakdown of my entire $13 million d...  finance
# 2  I saved 20 cents on my iced coffee by not drin...  finance
# 3  I can't express how grateful I am for this ins...  finance
# 4  This guy got bad grades in high school? Nuff s...  finance

# %%
news.head()
# Out:
#    Unnamed: 0                                            comment label
# 0           0  SKIP NAVIGATION\nSIGN IN\n0:00 / 6:07\n#Fauci ...  news
# 1           1                                                NaN  news
# 2           2  Dr. Anthony Fauci speaks with NBC News’ Lester...  news
# 3           3  What a waste of time... this guy is spinning. ...  news
# 4           4  I don't know how to deal with the virus. Going...  news

# %%
tech.columns = ['comment', 'label']

# %%
tech.head()
# Out:
#                                              comment label
# 0  Checkout the video we made on Clem's channel w...  tech
# 1  Do you know what the scariest thing in the wor...  tech
# 2  so i work for him and he works for you...? i m...  tech
# 3  How front end interviews should be: This video...  tech
# 4               gender: “female”\nname: Object\n8:32  tech

# %%
clean_news = news[['comment', 'label']]

# %%
clean_news.head()
# Out:
#                                              comment label
# 0  SKIP NAVIGATION\nSIGN IN\n0:00 / 6:07\n#Fauci ...  news
# 1                                                NaN  news
# 2  Dr. Anthony Fauci speaks with NBC News’ Lester...  news
# 3  What a waste of time... this guy is spinning. ...  news
# 4  I don't know how to deal with the virus. Going...  news

# %%
clean_news.drop([0,1])
# Out:
#                                                 comment label
# 2     Dr. Anthony Fauci speaks with NBC News’ Lester...  news
# 3     What a waste of time... this guy is spinning. ...  news
# 4     I don't know how to deal with the virus. Going...  news
# 5     No reason to take the vaccine since we’re neve...  news
# 6     this clown hasn't been right about anything wh...  news
# ...                                                 ...   ...
# 1740  I admire Lindsay Graham. His commitment to go ...  news
# 1741                             ❤️ MLKs granddaughter.  news
# 1742  more more more fear fear who's tell you to do ...  news
# 1743  From Tokyo Thank You Very much for news hie pl...  news
# 1744                                          Nice work  news
#
# [1743 rows x 2 columns]

# %%
clean_finance = finance.copy(deep = True)

# %%
clean_finance.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             0
# 1           1             1
# 2           2             2
# 3           3             3
# 4           4             4
#
#                                              comment    label
# 0  SKIP NAVIGATION\nSIGN IN\n0:01 / 26:51\nReveal...  finance
# 1  Here is a breakdown of my entire $13 million d...  finance
# 2  I saved 20 cents on my iced coffee by not drin...  finance
# 3  I can't express how grateful I am for this ins...  finance
# 4  This guy got bad grades in high school? Nuff s...  finance

# %%
clean_finance = clean_finance[['comment', 'label']]

# %%
clean_finance.head()
# Out:
#                                              comment    label
# 0  SKIP NAVIGATION\nSIGN IN\n0:01 / 26:51\nReveal...  finance
# 1  Here is a breakdown of my entire $13 million d...  finance
# 2  I saved 20 cents on my iced coffee by not drin...  finance
# 3  I can't express how grateful I am for this ins...  finance
# 4  This guy got bad grades in high school? Nuff s...  finance

# %%
clean_finance.drop([0])
# Out:
#                                                comment    label
# 1    Here is a breakdown of my entire $13 million d...  finance
# 2    I saved 20 cents on my iced coffee by not drin...  finance
# 3    I can't express how grateful I am for this ins...  finance
# 4    This guy got bad grades in high school? Nuff s...  finance
# 5                                Goals, actual goals!!  finance
# ..                                                 ...      ...
# 884  LOL this is gonna be great. Hoping for the tri...  finance
# 885          I actually want to know how this will end  finance
# 886  So dreams do come true! Am so fired up for this 😁  finance
# 887  No doubt this is creative and brilliant way in...  finance
# 888  This is like someone doing DD on Wallstreet bets.  finance
#
# [888 rows x 2 columns]

# %%
clean_tech = tech

# %%
clean_tech
# Out:
#                                                 comment label
# 0     Checkout the video we made on Clem's channel w...  tech
# 1     Do you know what the scariest thing in the wor...  tech
# 2     so i work for him and he works for you...? i m...  tech
# 3     How front end interviews should be: This video...  tech
# 4                  gender: “female”\nname: Object\n8:32  tech
# ...                                                 ...   ...
# 1792  So i needed to watch this video but had to che...  tech
# 1793   this worst there is no explanation for newbiiees  tech
# 1794  you are just coding but you are not giving kno...  tech
# 1795                                                NaN  tech
# 1796                                                NaN  tech
#
# [1797 rows x 2 columns]

# %%
beauty.head()
# Out:
#    Unnamed: 0                                            comment   label
# 0           0  SKIP NAVIGATION\nSIGN IN\nSplitsies :15 | Toni...  beauty
# 1           1  😍 Subscribe to my channel : http://bit.ly/2hjb...  beauty
# 2           2  I don't know why but her voice is oddly satisf...  beauty
# 3           3  Me who doesn't even have half of the stuff I n...  beauty
# 4           4  I  cant believe this is how she actually sound...  beauty

# %%
clean_beauty = beauty[['comment', 'label']]

# %%
clean_beauty
# Out:
#                                                 comment   label
# 0     SKIP NAVIGATION\nSIGN IN\nSplitsies :15 | Toni...  beauty
# 1     😍 Subscribe to my channel : http://bit.ly/2hjb...  beauty
# 2     I don't know why but her voice is oddly satisf...  beauty
# 3     Me who doesn't even have half of the stuff I n...  beauty
# 4     I  cant believe this is how she actually sound...  beauty
# ...                                                 ...     ...
# 2499           She is so pretty! I love the ice method!  beauty
# 2500  Her lashes are so long. And her skin is amazin...  beauty
# 2501  She loves those products so much that she call...  beauty
# 2502  nobody:\nmadelaine: beeing naturally beautiful...  beauty
# 2503                                                NaN  beauty
#
# [2504 rows x 2 columns]

# %%
clean_beauty.drop([0])
# Out:
#                                                 comment   label
# 1     😍 Subscribe to my channel : http://bit.ly/2hjb...  beauty
# 2     I don't know why but her voice is oddly satisf...  beauty
# 3     Me who doesn't even have half of the stuff I n...  beauty
# 4     I  cant believe this is how she actually sound...  beauty
# 5     Okay, it’s been three minutes and I’ve said “ ...  beauty
# ...                                                 ...     ...
# 2499           She is so pretty! I love the ice method!  beauty
# 2500  Her lashes are so long. And her skin is amazin...  beauty
# 2501  She loves those products so much that she call...  beauty
# 2502  nobody:\nmadelaine: beeing naturally beautiful...  beauty
# 2503                                                NaN  beauty
#
# [2503 rows x 2 columns]

# %%
frames = [clean_beauty, clean_tech, clean_news, clean_finance]

# %%
raw_df = pd.concat(frames)

# %%
raw_df.reset_index()
# Out:
#       index                                            comment    label
# 0         0  SKIP NAVIGATION\nSIGN IN\nSplitsies :15 | Toni...   beauty
# 1         1  😍 Subscribe to my channel : http://bit.ly/2hjb...   beauty
# 2         2  I don't know why but her voice is oddly satisf...   beauty
# 3         3  Me who doesn't even have half of the stuff I n...   beauty
# 4         4  I  cant believe this is how she actually sound...   beauty
# ...     ...                                                ...      ...
# 6930    884  LOL this is gonna be great. Hoping for the tri...  finance
# 6931    885          I actually want to know how this will end  finance
# 6932    886  So dreams do come true! Am so fired up for this 😁  finance
# 6933    887  No doubt this is creative and brilliant way in...  finance
# 6934    888  This is like someone doing DD on Wallstreet bets.  finance
#
# [6935 rows x 3 columns]

# %%
raw_df = raw_df[['comment', 'label']]

# %%
raw_df
# Out:
#                                                comment    label
# 0    SKIP NAVIGATION\nSIGN IN\nSplitsies :15 | Toni...   beauty
# 1    😍 Subscribe to my channel : http://bit.ly/2hjb...   beauty
# 2    I don't know why but her voice is oddly satisf...   beauty
# 3    Me who doesn't even have half of the stuff I n...   beauty
# 4    I  cant believe this is how she actually sound...   beauty
# ..                                                 ...      ...
# 884  LOL this is gonna be great. Hoping for the tri...  finance
# 885          I actually want to know how this will end  finance
# 886  So dreams do come true! Am so fired up for this 😁  finance
# 887  No doubt this is creative and brilliant way in...  finance
# 888  This is like someone doing DD on Wallstreet bets.  finance
#
# [6935 rows x 2 columns]

# %%
raw_df.reset_index(inplace = True)

# %%
raw_df = raw_df[['comment', 'label']]

# %%
raw_df
# Out:
#                                                 comment    label
# 0     SKIP NAVIGATION\nSIGN IN\nSplitsies :15 | Toni...   beauty
# 1     😍 Subscribe to my channel : http://bit.ly/2hjb...   beauty
# 2     I don't know why but her voice is oddly satisf...   beauty
# 3     Me who doesn't even have half of the stuff I n...   beauty
# 4     I  cant believe this is how she actually sound...   beauty
# ...                                                 ...      ...
# 6930  LOL this is gonna be great. Hoping for the tri...  finance
# 6931          I actually want to know how this will end  finance
# 6932  So dreams do come true! Am so fired up for this 😁  finance
# 6933  No doubt this is creative and brilliant way in...  finance
# 6934  This is like someone doing DD on Wallstreet bets.  finance
#
# [6935 rows x 2 columns]

# %%
raw_df.to_csv('comment_data.csv')
